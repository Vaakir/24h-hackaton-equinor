# %%
import requests
import pandas as pd

url = "https://www.yr.no/api/v0/locations/1-72837/observations/2023-02-10"
response = requests.get(url)
data = response.json()
df=[{"temp":d["temperature"]["value"], "wind":d["wind"]["meanSpeed"], "time":d["time"]} for d in data["historical"]["days"][0]["hours"]]
df = pd.DataFrame(df)
df
# Out:
#     temp  wind                       time
# 0    1.3   4.8  2023-02-10T01:00:00+01:00
# 1    1.0   5.6  2023-02-10T02:00:00+01:00
# 2    0.7   4.8  2023-02-10T03:00:00+01:00
# 3    0.2   3.8  2023-02-10T04:00:00+01:00
# 4    0.6   6.1  2023-02-10T05:00:00+01:00
# 5   -0.4   3.3  2023-02-10T06:00:00+01:00
# 6   -0.2   4.0  2023-02-10T07:00:00+01:00
# 7   -0.6   4.4  2023-02-10T08:00:00+01:00
# 8   -0.3   3.3  2023-02-10T09:00:00+01:00
# 9    0.0   3.7  2023-02-10T10:00:00+01:00
# 10   0.1   4.2  2023-02-10T11:00:00+01:00
# 11   0.5   3.3  2023-02-10T12:00:00+01:00
# 12   0.5   2.9  2023-02-10T13:00:00+01:00
# 13   1.0   3.2  2023-02-10T14:00:00+01:00
# 14  -0.2   4.5  2023-02-10T15:00:00+01:00
# 15  -1.2   4.5  2023-02-10T16:00:00+01:00
# 16  -0.7   1.9  2023-02-10T17:00:00+01:00
# 17   0.3   1.8  2023-02-10T18:00:00+01:00
# 18   1.7   3.0  2023-02-10T19:00:00+01:00
# 19   3.4   4.7  2023-02-10T20:00:00+01:00
# 20   3.4   4.0  2023-02-10T21:00:00+01:00
# ...

# %%
import requests
import pandas as pd
from datetime import datetime, timedelta

# Define the start and end dates
start_date = datetime(2013, 1, 1)
end_date = datetime(2014, 12, 31)

# Initialize an empty list to store data
all_data = []

# Loop through each date
current_date = start_date
while current_date <= end_date:
    date_str = current_date.strftime("%Y-%m-%d")  # Format date as YYYY-MM-DD
    print(date_str)
    url = f"https://www.yr.no/api/v0/locations/1-72837/observations/{date_str}"

    try:
        response = requests.get(url)
        response.raise_for_status()  # Raise an error for failed requests
        data = response.json()
        
        # Extract hourly observations if available
        if "historical" in data and "days" in data["historical"] and data["historical"]["days"]:
            for hour in data["historical"]["days"][0]["hours"]:
                all_data.append({
                    "date": date_str,
                    "time": hour["time"],
                    "temperature": hour["temperature"]["value"] if "temperature" in hour and "value" in hour["temperature"] else None,
                    "wind_speed": hour["wind"]["meanSpeed"] if "wind" in hour and "meanSpeed" in hour["wind"] else None
                })
    except:
        print(f"Failed to fetch data for {date_str}")

    # Move to the next day
    current_date += timedelta(days=1)

# Convert the collected data into a DataFrame
df = pd.DataFrame(all_data)

# Save to JSON file
df.to_json("weather_data_2010_2014.json", orient="records", index=False)

print("Download complete. Data saved to 'weather_data_2010_2014.json'")
# Out:
# 2013-01-01
# 2013-01-02
# 2013-01-03
# 2013-01-04
# 2013-01-05
# 2013-01-06
# 2013-01-07
# 2013-01-08
# 2013-01-09
# 2013-01-10
# 2013-01-11
# 2013-01-12
# 2013-01-13
# 2013-01-14
# 2013-01-15
# 2013-01-16
# 2013-01-17
# 2013-01-18
# 2013-01-19
# 2013-01-20
# 2013-01-21
# 2013-01-22
# 2013-01-23
# 2013-01-24
# 2013-01-25
# 2013-01-26
# 2013-01-27
# 2013-01-28
# 2013-01-29
# 2013-01-30
# 2013-01-31
# 2013-02-01
# 2013-02-02
# 2013-02-03
# 2013-02-04
# 2013-02-05
# 2013-02-06
# 2013-02-07
# 2013-02-08
# 2013-02-09
# 2013-02-10
# 2013-02-11
# 2013-02-12
# 2013-02-13
# 2013-02-14
# 2013-02-15
# 2013-02-16
# 2013-02-17
# 2013-02-18
# 2013-02-19
# 2013-02-20
# 2013-02-21
# 2013-02-22
# 2013-02-23
# 2013-02-24
# 2013-02-25
# 2013-02-26
# 2013-02-27
# 2013-02-28
# 2013-03-01
# 2013-03-02
# 2013-03-03
# 2013-03-04
# 2013-03-05
# 2013-03-06
# 2013-03-07
# 2013-03-08
# 2013-03-09
# 2013-03-10
# 2013-03-11
# 2013-03-12
# 2013-03-13
# 2013-03-14
# 2013-03-15
# 2013-03-16
# 2013-03-17
# ...
