# %%
import pandas as pd
from glob import glob
from matplotlib import pyplot as plt

# %%
df = pd.read_csv("statnett-production-consumption.csv")
df["Time(Local)"] = pd.to_datetime(df["Time(Local)"], format="%d.%m.%Y %H:%M:%S %z")
df.drop(inplace=True, columns = "Unnamed: 0")
df
# Out:
# C:\Users\PieHu\AppData\Local\Temp\ipykernel_31152\3524956930.py:2: FutureWarning: In a future version of pandas, parsing datetimes with mixed time zones will raise an error unless `utc=True`. Please specify `utc=True` to opt in to the new behaviour and silence this warning. To create a `Series` with mixed offsets and `object` dtype, please use `apply` and `datetime.datetime.strptime`
#   df["Time(Local)"] = pd.to_datetime(df["Time(Local)"], format="%d.%m.%Y %H:%M:%S %z")
#                       Time(Local)  Production  Consumption
# 0       2001-01-01 00:00:00+01:00       17571        17537
# 1       2001-01-01 01:00:00+01:00       16929        17163
# 2       2001-01-01 02:00:00+01:00       16388        17038
# 3       2001-01-01 03:00:00+01:00       15682        16823
# 4       2001-01-01 04:00:00+01:00       15150        16532
# ...                           ...         ...          ...
# 210225  2025-02-14 19:00:00+01:00       25272        21109
# ...

# %%
# df.to_csv("statnett-production-consumption.csv")

# %%
plt.plot(df["Time(Local)"], df["Production"])
plt.show()
plt.scatter(df["Consumption"], df["Production"])

# %%
# Out:
#         Unnamed: 0                 Time(Local)  Production  Consumption
# 0                0  01.01.2001 00:00:00 +01:00       17571        17537
# 1                1  01.01.2001 01:00:00 +01:00       16929        17163
# 2                2  01.01.2001 02:00:00 +01:00       16388        17038
# 3                3  01.01.2001 03:00:00 +01:00       15682        16823
# 4                4  01.01.2001 04:00:00 +01:00       15150        16532
# ...            ...                         ...         ...          ...
# 210225        1075  14.02.2025 19:00:00 +01:00       25272        21109
# 210226        1076  14.02.2025 20:00:00 +01:00       25531        20701
# 210227        1077  14.02.2025 21:00:00 +01:00       25776        20355
# 210228        1078  14.02.2025 22:00:00 +01:00       25706        19855
# 210229        1079  14.02.2025 23:00:00 +01:00       25683        19621
#
# [210230 rows x 4 columns]

# %%
import pandas as pd

df=pd.read_csv("statnett-production-consumption.csv")
df["Consumption"].to_json("statnett-production-consumption.json",orient="records",index=False)
